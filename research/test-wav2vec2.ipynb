# %% [markdown]
# https://huggingface.co/facebook/wav2vec2-large-960h

# %%
# Uninstall the current version of NumPy
# !pip uninstall -y numpy

# Install a compatible version of NumPy
# !pip install numpy==1.21.0  # Example version, adjust as needed
# Out:
# Found existing installation: numpy 2.0.1
# Uninstalling numpy-2.0.1:
#   Successfully uninstalled numpy-2.0.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 2.3 MB/s eta 0:00:0000:010:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for numpy: filename=numpy-1.21.0-cp310-cp310-macosx_12_0_arm64.whl size=4560855 sha256=c1830ee0d99a4e85c8c99850b3006b1de93d61df6cc824268b07c9f9da8733ab
#   Stored in directory: /Users/ngocp/Library/Caches/pip/wheels/05/61/d1/ccc2cd557b39e127ad98a392d9558f3c5dda28764b7f54b2f5
# Successfully built numpy
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^
# ...

# %%
import torch
import torchaudio
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# Load the processor and model
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-large-960h")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 import torch
#       2 import torchaudio
# ----> 3 from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
#       5 # Load the processor and model
#       6 processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h")
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/transformers/__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# ...

# %%
# Function to preprocess audio
def preprocess_audio(file_path):
    # Load audio file
    speech_array, sampling_rate = torchaudio.load(file_path)
    
    # Resample if necessary
    if sampling_rate != 16000:
        resampler = torchaudio.transforms.Resample(sampling_rate, 16000)
        speech_array = resampler(speech_array)
    
    # Preprocess audio
    input_values = processor(speech_array.squeeze().numpy(), return_tensors="pt", sampling_rate=16000).input_values
    return input_values

# %%
path = "./outputs/voice-1721559897.wav"
sample_data = preprocess_audio(path)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 path = "./outputs/voice-1721559897.wav"
# ----> 2 sample_data = preprocess_audio(path)
#
# Cell In[4], line 12, in preprocess_audio(file_path)
#       9     speech_array = resampler(speech_array)
#      11 # Preprocess audio
# ---> 12 input_values = processor(speech_array.squeeze().numpy(), return_tensors="pt", sampling_rate=16000).input_values
#      13 return input_values
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/transformers/models/wav2vec2/processing_wav2vec2.py:95, in Wav2Vec2Processor.__call__(self, *args, **kwargs)
# ...

# %%
result = model(sample_data).logits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result = model(sample_data).logits
#
# NameError: name 'model' is not defined
