# %% [markdown]
# https://huggingface.co/facebook/wav2vec2-large-960h

# %%
import torch
import torchaudio
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# Load the processor and model
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-large-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-large-960h")
# Out:
# /Users/ngocp/.pyenv/versions/3.10.3/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'dlopen(/Users/ngocp/.pyenv/versions/3.10.3/lib/python3.10/site-packages/torchvision/image.so, 0x0006): Symbol not found: (__ZN3c1017RegisterOperatorsD1Ev)
#   Referenced from: '/Users/ngocp/.pyenv/versions/3.10.3/lib/python3.10/site-packages/torchvision/image.so'
#   Expected in: '/Users/ngocp/.pyenv/versions/3.10.3/lib/python3.10/site-packages/torch/lib/libtorch_cpu.dylib''If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# Some weights of the model checkpoint at facebook/wav2vec2-large-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !pip install --upgrade pip
# !pip install --upgrade numpy
# Out:
# Requirement already satisfied: pip in /Users/ngocp/.pyenv/versions/3.10.3/lib/python3.10/site-packages (24.1.2)
# Collecting pip
#   Downloading pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 1.5 MB/s eta 0:00:0000:0100:010m
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.2
# Requirement already satisfied: numpy in /Users/ngocp/.pyenv/versions/3.10.3/lib/python3.10/site-packages (2.0.1)
# WARNING: Error parsing dependencies of textract: .* suffix can only be used with `==` or `!=` operators
#     extract-msg (<=0.29.*)
#                  ~~~~~~~^

# %%
from datasets import load_dataset 
# load dummy dataset and read soundfiles
ds = load_dataset("patrickvonplaten/librispeech_asr_dummy", "clean", split="validation")
# Out:
# Found cached dataset librispeech_asr_dummy (/Users/ngocp/.cache/huggingface/datasets/patrickvonplaten___librispeech_asr_dummy/clean/2.1.0/f2c70a4d03ab4410954901bde48c54b85ca1b7f9bf7d616e7e2a72b5ee6ddbfc)

# %%
print(ds[0])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(ds[0])
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/arrow_dataset.py:2792, in Dataset.__getitem__(self, key)
#    2790 def __getitem__(self, key):  # noqa: F811
#    2791     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2792     return self._getitem(key)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/arrow_dataset.py:2777, in Dataset._getitem(self, key, **kwargs)
#    2775 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    2776 pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 2777 formatted_output = format_table(
#    2778     pa_subtable, key, formatter=formatter, format_columns=format_columns, output_all_columns=output_all_columns
#    2779 )
#    2780 return formatted_output
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/formatting/formatting.py:629, in format_table(table, key, formatter, format_columns, output_all_columns)
#     627 python_formatter = PythonFormatter(features=None)
#     628 if format_columns is None:
# --> 629     return formatter(pa_table, query_type=query_type)
#     630 elif query_type == "column":
#     631     if key in format_columns:
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/formatting/formatting.py:396, in Formatter.__call__(self, pa_table, query_type)
#     394 def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFormat, BatchFormat]:
#     395     if query_type == "row":
# --> 396         return self.format_row(pa_table)
#     397     elif query_type == "column":
#     398         return self.format_column(pa_table)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/formatting/formatting.py:437, in PythonFormatter.format_row(self, pa_table)
#     435     return LazyRow(pa_table, self)
#     436 row = self.python_arrow_extractor().extract_row(pa_table)
# --> 437 row = self.python_features_decoder.decode_row(row)
#     438 return row
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/formatting/formatting.py:215, in PythonFeaturesDecoder.decode_row(self, row)
#     214 def decode_row(self, row: dict) -> dict:
# --> 215     return self.features.decode_example(row) if self.features else row
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/features/features.py:1902, in Features.decode_example(self, example, token_per_repo_id)
#    1888 def decode_example(self, example: dict, token_per_repo_id: Optional[Dict[str, Union[str, bool, None]]] = None):
#    1889     """Decode example with custom feature decoding.
#    1890
#    1891     Args:
#    (...)
#    1899         `dict[str, Any]`
#    1900     """
# -> 1902     return {
#    1903         column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    1904         if self._column_requires_decoding[column_name]
#    1905         else value
#    1906         for column_name, (feature, value) in zip_dict(
#    1907             {key: value for key, value in self.items() if key in example}, example
#    1908         )
#    1909     }
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/features/features.py:1903, in <dictcomp>(.0)
#    1888 def decode_example(self, example: dict, token_per_repo_id: Optional[Dict[str, Union[str, bool, None]]] = None):
#    1889     """Decode example with custom feature decoding.
#    1890
#    1891     Args:
#    (...)
#    1899         `dict[str, Any]`
#    1900     """
#    1902     return {
# -> 1903         column_name: decode_nested_example(feature, value, token_per_repo_id=token_per_repo_id)
#    1904         if self._column_requires_decoding[column_name]
#    1905         else value
#    1906         for column_name, (feature, value) in zip_dict(
#    1907             {key: value for key, value in self.items() if key in example}, example
#    1908         )
#    1909     }
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/features/features.py:1325, in decode_nested_example(schema, obj, token_per_repo_id)
#    1322 elif isinstance(schema, (Audio, Image)):
#    1323     # we pass the token to read and decode files from private repositories in streaming mode
#    1324     if obj is not None and schema.decode:
# -> 1325         return schema.decode_example(obj, token_per_repo_id=token_per_repo_id)
#    1326 return obj
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/datasets/features/audio.py:189, in Audio.decode_example(self, value, token_per_repo_id)
#     187 array = array.T
#     188 if self.mono:
# --> 189     array = librosa.to_mono(array)
#     190 if self.sampling_rate and self.sampling_rate != sampling_rate:
#     191     array = librosa.resample(array, orig_sr=sampling_rate, target_sr=self.sampling_rate)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/lazy_loader/__init__.py:78, in attach.<locals>.__getattr__(name)
#      76 submod_path = f"{package_name}.{attr_to_modules[name]}"
#      77 submod = importlib.import_module(submod_path)
# ---> 78 attr = getattr(submod, name)
#      80 # If the attribute lives in a file (module) with the same
#      81 # name as the attribute, ensure that the attribute and *not*
#      82 # the module is accessible on the package.
#      83 if name == attr_to_modules[name]:
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/lazy_loader/__init__.py:77, in attach.<locals>.__getattr__(name)
#      75 elif name in attr_to_modules:
#      76     submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 77     submod = importlib.import_module(submod_path)
#      78     attr = getattr(submod, name)
#      80     # If the attribute lives in a file (module) with the same
#      81     # name as the attribute, ensure that the attribute and *not*
#      82     # the module is accessible on the package.
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/librosa/core/audio.py:17
#      14 import soxr
#      15 import lazy_loader as lazy
# ---> 17 from numba import jit, stencil, guvectorize
#      18 from .fft import get_fftlib
#      19 from .convert import frames_to_samples, time_to_samples
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/numba/__init__.py:55
#      50             msg = ("Numba requires SciPy version 1.0 or greater. Got SciPy "
#      51                    f"{scipy.__version__}.")
#      52             raise ImportError(msg)
# ---> 55 _ensure_critical_deps()
#      56 # END DO NOT MOVE
#      57 # ---------------------- WARNING WARNING WARNING ----------------------------
#      60 from ._version import get_versions
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/numba/__init__.py:40, in _ensure_critical_deps()
#      37 if numpy_version < (1, 22):
#      38     msg = (f"Numba needs NumPy 1.22 or greater. Got NumPy "
#      39            f"{numpy_version[0]}.{numpy_version[1]}.")
# ---> 40     raise ImportError(msg)
#      41 elif numpy_version > (1, 26):
#      42     raise ImportError("Numba needs NumPy 1.26 or less")
#
# ImportError: Numba needs NumPy 1.22 or greater. Got NumPy 1.21.

# %%
 # tokenize
input_values = processor(ds[0]["audio"]["array"],, return_tensors="pt", padding="longest").input_values  # Batch size 1

# %%
# Function to preprocess audio
def preprocess_audio(file_path):
    # Load audio file
    speech_array, sampling_rate = torchaudio.load(file_path)
    
    # Resample if necessary
    if sampling_rate != 16000:
        resampler = torchaudio.transforms.Resample(sampling_rate, 16000)
        speech_array = resampler(speech_array)
    
    # Preprocess audio
    input_values = processor(speech_array.squeeze().numpy(), return_tensors="pt", sampling_rate=16000).input_values
    return input_values

# %%
path = "./outputs/voice-1721559897.wav"
sample_data = preprocess_audio(path)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 path = "./outputs/voice-1721559897.wav"
# ----> 2 sample_data = preprocess_audio(path)
#
# Cell In[2], line 12, in preprocess_audio(file_path)
#       9     speech_array = resampler(speech_array)
#      11 # Preprocess audio
# ---> 12 input_values = processor(speech_array.squeeze().numpy(), return_tensors="pt", sampling_rate=16000).input_values
#      13 return input_values
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/transformers/models/wav2vec2/processing_wav2vec2.py:95, in Wav2Vec2Processor.__call__(self, *args, **kwargs)
#      92     raise ValueError("You need to specify either an `audio` or `text` input to process.")
#      94 if audio is not None:
# ---> 95     inputs = self.feature_extractor(audio, *args, sampling_rate=sampling_rate, **kwargs)
#      96 if text is not None:
#      97     encodings = self.tokenizer(text, **kwargs)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/transformers/models/wav2vec2/feature_extraction_wav2vec2.py:199, in Wav2Vec2FeatureExtractor.__call__(self, raw_speech, padding, max_length, truncation, pad_to_multiple_of, return_attention_mask, return_tensors, sampling_rate, **kwargs)
#     196 # convert into correct format for padding
#     197 encoded_inputs = BatchFeature({"input_values": raw_speech})
# --> 199 padded_inputs = self.pad(
#     200     encoded_inputs,
#     201     padding=padding,
#     202     max_length=max_length,
#     203     truncation=truncation,
#     204     pad_to_multiple_of=pad_to_multiple_of,
#     205     return_attention_mask=return_attention_mask,
#     206 )
#     208 # convert input values to correct format
#     209 input_values = padded_inputs["input_values"]
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/transformers/feature_extraction_sequence_utils.py:163, in SequenceFeatureExtractor.pad(self, processed_features, padding, max_length, truncation, pad_to_multiple_of, return_attention_mask, return_tensors)
#     160         first_element = required_input[index][0]
#     162 if return_tensors is None:
# --> 163     if is_tf_tensor(first_element):
#     164         return_tensors = "tf"
#     165     elif is_torch_tensor(first_element):
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/transformers/utils/generic.py:208, in is_tf_tensor(x)
#     204 def is_tf_tensor(x):
#     205     """
#     206     Tests if `x` is a tensorflow tensor or not. Safe to call even if tensorflow is not installed.
#     207     """
# --> 208     return False if not is_tf_available() else _is_tensorflow(x)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/transformers/utils/generic.py:199, in _is_tensorflow(x)
#     198 def _is_tensorflow(x):
# --> 199     import tensorflow as tf
#     201     return isinstance(x, tf.Tensor)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from tensorflow._api.v2 import __internal__
#      46 from tensorflow._api.v2 import __operators__
#      47 from tensorflow._api.v2 import audio
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/__init__.py:11
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#      13 from tensorflow._api.v2.__internal__ import feature_column
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/distribute/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.distribute namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#      10 from tensorflow._api.v2.__internal__.distribute import multi_process_runner
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/_api/v2/__internal__/distribute/combinations/__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.distribute.combinations namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#      10 from tensorflow.python.distribute.combinations import in_main_process # line: 418
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/distribute/combinations.py:33
#      29 import six
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#      35 from tensorflow.python.distribute import multi_process_runner
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/distribute/collective_all_reduce_strategy.py:25
#      23 from tensorflow.core.protobuf import tensorflow_server_pb2
#      24 from tensorflow.python.distribute import collective_util
# ---> 25 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      26 from tensorflow.python.distribute import cross_device_utils
#      27 from tensorflow.python.distribute import device_util
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/distribute/cross_device_ops.py:28
#      26 from tensorflow.python.client import device_lib
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#      30 from tensorflow.python.distribute import distribute_utils
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/distribute/cross_device_utils.py:22
#      19 from typing import Callable, List, Optional, Union
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#      24 from tensorflow.python.eager import context
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/distribute/values.py:23
#      21 from tensorflow.core.protobuf import struct_pb2
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#      25 from tensorflow.python.distribute import reduce_util
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/distribute/distribute_lib.py:205
#     203 from tensorflow.python.autograph.core import ag_ctx as autograph_ctx
#     204 from tensorflow.python.autograph.impl import api as autograph
# --> 205 from tensorflow.python.data.ops import dataset_ops
#     206 from tensorflow.python.distribute import collective_util
#     207 from tensorflow.python.distribute import device_util
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/data/__init__.py:21
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/data/experimental/__init__.py:97
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      93 @@UNKNOWN_CARDINALITY
#      94 """
#      96 # pylint: disable=unused-import
# ---> 97 from tensorflow.python.data.experimental import service
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/data/experimental/service/__init__.py:419
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py:26
#      24 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      25 from tensorflow.python.data.experimental.service import _pywrap_utils
# ---> 26 from tensorflow.python.data.ops import dataset_ops
#      27 from tensorflow.python.data.ops import options as options_lib
#      28 from tensorflow.python.data.ops import structured_function
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:34
#      32 from tensorflow.python.data.ops import dataset_autograph
#      33 from tensorflow.python.data.ops import debug_mode
# ---> 34 from tensorflow.python.data.ops import iterator_ops
#      35 from tensorflow.python.data.ops import options as options_lib
#      36 from tensorflow.python.data.ops import structured_function
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/data/ops/iterator_ops.py:41
#      39 from tensorflow.python.saved_model import nested_structure_coder
#      40 from tensorflow.python.trackable import base as trackable
# ---> 41 from tensorflow.python.training.saver import BaseSaverBuilder
#      42 from tensorflow.python.util import deprecation
#      43 from tensorflow.python.util.compat import collections_abc
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/training/saver.py:50
#      48 from tensorflow.python.saved_model.pywrap_saved_model import metrics
#      49 from tensorflow.python.trackable import base as trackable
# ---> 50 from tensorflow.python.training import py_checkpoint_reader
#      51 from tensorflow.python.training import training_util
#      52 from tensorflow.python.training.saving import saveable_object
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/tensorflow/python/training/py_checkpoint_reader.py:19
#      17 from tensorflow.python.framework import errors_impl
#      18 from tensorflow.python.util import compat
# ---> 19 from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
#      20 from tensorflow.python.util.tf_export import tf_export
#      23 def error_translator(e):
#
# SystemError: initialization of _pywrap_checkpoint_reader raised unreported exception

# %%
result = model(sample_data).logits
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 result = model(sample_data).logits
#
# NameError: name 'model' is not defined
